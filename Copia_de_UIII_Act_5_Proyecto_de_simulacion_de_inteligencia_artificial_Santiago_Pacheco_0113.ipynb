# %% [markdown]
# <a href="https://colab.research.google.com/github/santiagopacheco128/UIII-Act-5-Proyecto-de-simulacion-de-inteligencia-artificial-santaigo-0113/blob/main/Copia_de_UIII_Act_5_Proyecto_de_simulacion_de_inteligencia_artificial_Santiago_Pacheco_0113.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### santiago pacheco nl = 43
# ### clase : Actor
# ![texto del vínculo](https://raw.githubusercontent.com/santiagopacheco128/UIII-Act-5-Proyecto-de-simulacion-de-inteligencia-artificial-santaigo-0113/refs/heads/main/infografiaactor0113.png)

# %%
print("SISTEMA DE SELECCIÓN DE ACTORES")

nombre = input("Nombre del actor: ")
edad = int(input("Edad del actor: "))
experiencia = int(input("Años de experiencia: "))
genero = input("Género favorito (accion/drama/comedia): ")

if edad >= 30 and experiencia >= 5:
    print(nombre, "es candidato para papel principal")

elif edad >= 18 and experiencia >= 2:
    print(nombre, "puede participar como actor secundario")

else:
    print(nombre, "necesita más experiencia")

if genero == "accion":
    print("Puede participar en películas de acción")

elif genero == "drama":
    print("Puede participar en películas dramáticas")

elif genero == "comedia":
    print("Puede participar en películas de comedia")

else:
    print("Género no registrado")

print("\nPrograma realizado por Santiago Pacheco NL = 47")
# Out:
# SISTEMA DE SELECCIÓN DE ACTORES
# Nombre del actor: niggerman
# Edad del actor: 67
# Años de experiencia: 30
# Género favorito (accion/drama/comedia): accion
# niggerman es candidato para papel principal
# Puede participar en películas de acción
#
# Programa realizado por Santiago Pacheco NL = 47

# %%
print("SISTEMA DE SELECCIÓN DE ACTORES")

nombre = input("Nombre del actor: ")
edad = int(input("Edad del actor: "))
experiencia = int(input("Años de experiencia: "))
genero = input("Género favorito (accion/drama/comedia): ")

if edad >= 30 and experiencia >= 5:
    print(nombre, "es candidato para papel principal")

elif edad >= 18 and experiencia >= 2:
    print(nombre, "puede participar como actor secundario")

else:
    print(nombre, "necesita más experiencia")

if genero == "accion":
    print("Puede participar en películas de acción")

elif genero == "drama":
    print("Puede participar en películas dramáticas")

elif genero == "comedia":
    print("Puede participar en películas de comedia")

else:
    print("Género no registrado")

print("\nPrograma realizado por Santiago Pacheco NL = 47")
# Out:
# SISTEMA DE SELECCIÓN DE ACTORES
# Nombre del actor: pacheco
# Edad del actor: 16
# Años de experiencia: 4
# Género favorito (accion/drama/comedia): comedia
# pacheco necesita más experiencia
# Puede participar en películas de comedia
#
# Programa realizado por Santiago Pacheco NL = 47

# %%
print("SISTEMA DE SELECCIÓN DE ACTORES")

nombre = input("Nombre del actor: ")
edad = int(input("Edad del actor: "))
experiencia = int(input("Años de experiencia: "))
genero = input("Género favorito (accion/drama/comedia): ")

if edad >= 30 and experiencia >= 5:
    print(nombre, "es candidato para papel principal")

elif edad >= 18 and experiencia >= 2:
    print(nombre, "puede participar como actor secundario")

else:
    print(nombre, "necesita más experiencia")

if genero == "accion":
    print("Puede participar en películas de acción")

elif genero == "drama":
    print("Puede participar en películas dramáticas")

elif genero == "comedia":
    print("Puede participar en películas de comedia")

else:
    print("Género no registrado")

print("\nPrograma realizado por Santiago Pacheco NL = 47")
# Out:
# SISTEMA DE SELECCIÓN DE ACTORES
# Nombre del actor: lolita
# Edad del actor: 45
# Años de experiencia: 6
# Género favorito (accion/drama/comedia): drama
# lolita es candidato para papel principal
# Puede participar en películas dramáticas
#
# Programa realizado por Santiago Pacheco NL = 47
